# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
def process_df(file_name):
    df=pd.read_csv(file_name,names=["Time:s","Time:us",'Window'],dtype=float)
    df["Time"]=df["Time:s"]+df["Time:us"]*(1.0/1000000) 
    return df

# %% [markdown]
# # Congestion Window with 0 Loss

# %%
df=process_df("CWND._loss=0.csv")

# %%
plt.plot(df["Time"],df["Window"])

# %% [markdown]
# # Congestion with with 10% packet Loss

# %%
df=process_df("CWND_downlink_loss=0.1.csv")

# %%
plt.plot(df["Time"],df["Window"])

# %% [markdown]
# # Congestion window with 10% ACK loss

# %%
df=process_df("CWND_uplink_loss=0.1.csv")

# %%
plt.plot(df["Time"],df["Window"])

# %% [markdown]
# # Delay of 1ms

# %%
df=process_df("CWND.csv")

# %%
plt.plot(df["Time"],df["Window"])

# %% [markdown]
# # Delay of 10ms
